# %%
#WORKS
import utils
import pandas as pd
import gensim
import topicModeling as tm
import importlib
import logging
from gensim.models import CoherenceModel
from pprint import pprint
# Plotting tools
import pyLDAvis
import pyLDAvis.gensim_models  # don't skip this
import matplotlib.pyplot as plt
from gensim.test.utils import datapath
import os
import numpy as np
# %matplotlib inline
# Out:
# /Users/jrod/anaconda3/envs/css_proj/lib/python3.7/site-packages/matplotlib_inline/config.py:66: DeprecationWarning: InlineBackend._figure_formats_changed is deprecated in traitlets 4.1: use @observe and @unobserve instead.
#   def _figure_formats_changed(self, name, old, new):

# %%
exists=True
#mallet_path = '../data/mallet-2.0.8/bin/mallet' DEPRECATED
import logging 
logging.basicConfig(filename='gensim.log',
                    format="%(asctime)s:%(levelname)s:%(message)s",
                    level=logging.DEBUG)

# %%
#split topic models by event
loc = utils.get_loc(None, exists=exists)
o_2020 = loc[loc['olympics'] == 2020]
o_2022 = loc[loc['olympics'] == 2022]

# %%
importlib.reload(tm)
#create dictionaries and corpuses
lda_df = tm.LDADF(o_2020)
dic_2020, corpus_2020, tokenized_2020 = lda_df.create_dic_and_corp()

lda_df = tm.LDADF(o_2022)
dic_2022, corpus_2022, tokenized_2022 = lda_df.create_dic_and_corp()
# Out:
# dic size: 2050
# dic size: 2615

# %%
'''mallet_keyword_dict = {"corpus":corpus,
                "id2word":dic,
                "num_topics":8,
                "iterations":100}'''
#optimal keywords for lda model generation
'''lda_keyword_dict_2020 = {"corpus":corpus_2020,
                "id2word":dic_2020,
                "num_topics":8,
                "iterations":100,
                "chunksize":15000,
                "passes":1,
                "alpha":'auto',
                "eta":'auto',
                "eval_every":None,
                "per_word_topics":True}'''

'''lda_keyword_dict_2022 = {"corpus":corpus_2022,
                "id2word":dic_2022,
                "num_topics":8,
                "iterations":100,
                "chunksize":15000,
                "passes":1,
                "alpha":'auto',
                "eta":'auto',
                "eval_every":None,
                "per_word_topics":True}'''
# Out:
# 'lda_keyword_dict_2022 = {"corpus":corpus_2022,\n                "id2word":dic_2022,\n                "num_topics":8,\n                "iterations":100,\n                "chunksize":15000,\n                "passes":1,\n                "alpha":\'auto\',\n                "eta":\'auto\',\n                "eval_every":None,\n                "per_word_topics":True}'

# %%
#Testing for optimal topic count 2020
'''models_2020 = []
scores_2020 = []
for i in range(1,20):
    lda_keyword_dict_2020['num_topics'] = i
    lda_model_2020 = gensim.models.LdaModel(**lda_keyword_dict_2020)
    scores_2020.append(CoherenceModel(model=lda_model_2020, texts=tokenized_2020, dictionary=dic_2020, coherence='u_mass').get_coherence())
    models_2020.append(lda_model_2020)'''
# Out:
# "models_2020 = []\nscores_2020 = []\nfor i in range(1,20):\n    lda_keyword_dict_2020['num_topics'] = i\n    lda_model_2020 = gensim.models.LdaModel(**lda_keyword_dict_2020)\n    scores_2020.append(CoherenceModel(model=lda_model_2020, texts=tokenized_2020, dictionary=dic_2020, coherence='u_mass').get_coherence())\n    models_2020.append(lda_model_2020)"

# %%
#Testing for optimal topic count 2022
'''models_2022 = []
scores_2022 = []
for i in range(1,20):
    lda_keyword_dict_2022['num_topics'] = i
    lda_model_2022 = gensim.models.LdaModel(**lda_keyword_dict_2022)
    scores_2022.append(CoherenceModel(model=lda_model_2022, texts=tokenized_2022, dictionary=dic_2022, coherence='u_mass').get_coherence())
    models_2022.append(lda_model_2022)'''
# Out:
# "models_2022 = []\nscores_2022 = []\nfor i in range(1,20):\n    lda_keyword_dict_2022['num_topics'] = i\n    lda_model_2022 = gensim.models.LdaModel(**lda_keyword_dict_2022)\n    scores_2022.append(CoherenceModel(model=lda_model_2022, texts=tokenized_2022, dictionary=dic_2022, coherence='u_mass').get_coherence())\n    models_2022.append(lda_model_2022)"

# %%
#comparable performance with worse interfacing
'''mallet_model = gensim.models.wrappers.LdaMallet(mallet_path=mallet_path, **mallet_keyword_dict)
coherence_lda = CoherenceModel(model=mallet_model, texts=tokenized, dictionary=dic, coherence='u_mass').get_coherence()
coherence_lda'''
# Out:
# "mallet_model = gensim.models.wrappers.LdaMallet(mallet_path=mallet_path, **mallet_keyword_dict)\ncoherence_lda = CoherenceModel(model=mallet_model, texts=tokenized, dictionary=dic, coherence='u_mass').get_coherence()\ncoherence_lda"

# %% [markdown]
# pyLDAvis.enable_notebook()
# vis = pyLDAvis.gensim_models.prepare(lda_model_2020, corpus_2020, dic_2020)
# vis

# %%
#used to save model
'''temp_file = datapath(os.getcwd() + '/model_2020')
models_2020[5].save(temp_file)'''
# Out:
# "temp_file = datapath(os.getcwd() + '/model_2020')\nmodels_2020[5].save(temp_file)"

# %%
#used to load model
model_2020 = gensim.models.LdaModel.load('../final_data/lda_models/model_2020')
CoherenceModel(model=model_2020, texts=tokenized_2020, dictionary=dic_2020, coherence='u_mass').get_coherence()
# Out:
# -10.044195739890792

# %%
#Note that the numbering of these topics don't map to the numbering of the final topics
pyLDAvis.enable_notebook() #3 meaningful topics
vis = pyLDAvis.gensim_models.prepare(model_2020, corpus_2020, dic_2020)
vis
# Out:
# /Users/jrod/anaconda3/envs/css_proj/lib/python3.7/site-packages/pyLDAvis/_prepare.py:247: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   by='saliency', ascending=False).head(R).drop('saliency', 1)
# /Users/jrod/anaconda3/envs/css_proj/lib/python3.7/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/jrod/anaconda3/envs/css_proj/lib/python3.7/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/jrod/anaconda3/envs/css_proj/lib/python3.7/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
# ...

# %%
#used to save model
'''temp_file = datapath(os.getcwd() + '/model_2022')
models_2022[5].save(temp_file)'''
# Out:
# "temp_file = datapath(os.getcwd() + '/model_2022')\nmodels_2022[5].save(temp_file)"

# %%
#used to load model
model_2022 = gensim.models.LdaModel.load('../final_data/lda_models/model_2022')
CoherenceModel(model=model_2022, texts=tokenized_2022, dictionary=dic_2022, coherence='u_mass').get_coherence()
# Out:
# -3.894607042942836

# %%
#Note that the numbering of these topics don't map to the numbering of the final topics
pyLDAvis.enable_notebook() # 5 meaningful topics
vis = pyLDAvis.gensim_models.prepare(model_2022, corpus_2022, dic_2022)
vis
# Out:
# /Users/jrod/anaconda3/envs/css_proj/lib/python3.7/site-packages/pyLDAvis/_prepare.py:247: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   by='saliency', ascending=False).head(R).drop('saliency', 1)
# /Users/jrod/anaconda3/envs/css_proj/lib/python3.7/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/jrod/anaconda3/envs/css_proj/lib/python3.7/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/jrod/anaconda3/envs/css_proj/lib/python3.7/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
# ...

# %%
#add topics to o_2020 df
topics_2020 = [0] * len(corpus_2020)
for i, row in enumerate(model_2020[corpus_2020]):
    row = sorted(row[0], key=lambda x: (x[1]), reverse=True)
    topics_2020[i] = row[0][0]
df_2020 = pd.DataFrame({'text':tokenized_2020, 'topic':topics_2020})
o_2020.loc[:,'topic'] = df_2020['topic'].values
# Out:
# /Users/jrod/anaconda3/envs/css_proj/lib/python3.7/site-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value

# %%
#add topics to o_2022 df
topics_2022 = [0] * len(corpus_2022)
for i, row in enumerate(model_2022[corpus_2022]):
    row = sorted(row[0], key=lambda x: (x[1]), reverse=True)
    topics_2022[i] = row[0][0]
df_2022 = pd.DataFrame({'text':tokenized_2022, 'topic':topics_2022})
o_2022.loc[:,'topic'] = df_2022.copy()['topic'].values

# %%
model_2020.print_topics()
# Out:
# [(0,
#   '0.038*"tokyo" + 0.033*"sport" + 0.021*"watch" + 0.016*"simone" + 0.016*"biles" + 0.014*"simone_biles" + 0.013*"japan" + 0.011*"tokyo2020" + 0.011*"year" + 0.009*"know"'),
#  (1,
#   '0.029*"watching" + 0.019*"tokyo" + 0.016*"tokyo2020" + 0.015*"watch" + 0.014*"track" + 0.013*"got" + 0.012*"great" + 0.010*"djokovic" + 0.010*"live" + 0.010*"ve"'),
#  (2,
#   '0.044*"team" + 0.021*"like" + 0.020*"usa" + 0.016*"tokyo" + 0.013*"time" + 0.013*"best" + 0.013*"athlete" + 0.011*"tokyo2020" + 0.010*"basketball" + 0.010*"men"'),
#  (3,
#   '0.031*"tokyo" + 0.027*"horse" + 0.025*"tokyo2020" + 0.021*"record" + 0.020*"tennis" + 0.020*"race" + 0.017*"app" + 0.016*"mixed" + 0.014*"set" + 0.014*"nbc"'),
#  (4,
#   '0.099*"gold" + 0.065*"medal" + 0.037*"win" + 0.029*"gold_medal" + 0.018*"tokyo" + 0.014*"love" + 0.013*"tokyo2020" + 0.010*"good" + 0.010*"na" + 0.009*"cyclingtrack"'),
#  (5,
# ...

# %%
#name topics:
o_2020['topic_name'] = None
o_2020.loc[o_2020['topic'] == 0, 'topic_name'] = 'SimoneBiles'
o_2020.loc[o_2020['topic'] == 1, 'topic_name'] = 'Other'
o_2020.loc[o_2020['topic'] == 2, 'topic_name'] = 'Other'
o_2020.loc[o_2020['topic'] == 3, 'topic_name'] = 'Other'
o_2020.loc[o_2020['topic'] == 4, 'topic_name'] = 'Cycling'
o_2020.loc[o_2020['topic'] == 5, 'topic_name'] = 'IndiaPride'
# Out:
# /Users/jrod/anaconda3/envs/css_proj/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/jrod/anaconda3/envs/css_proj/lib/python3.7/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
model_2022.print_topics()
# Out:
# [(0,
#   '0.013*"frozen" + 0.013*"winter" + 0.012*"frozen_penis" + 0.012*"penis" + 0.011*"skier" + 0.010*"beijing2022" + 0.010*"year" + 0.008*"finnish" + 0.008*"skating" + 0.008*"russian"'),
#  (1,
#   '0.020*"winter" + 0.017*"like" + 0.014*"know" + 0.012*"world" + 0.012*"sport" + 0.010*"event" + 0.009*"china" + 0.009*"watch" + 0.009*"beijing" + 0.008*"people"'),
#  (2,
#   '0.041*"ceremony" + 0.035*"closing" + 0.034*"beijing2022" + 0.032*"closing_ceremony" + 0.022*"winter" + 0.017*"beijing" + 0.015*"china" + 0.012*"live" + 0.010*"dwen" + 0.009*"yuzu"'),
#  (3,
#   '0.039*"winter" + 0.034*"beijing" + 0.025*"figure" + 0.024*"medal" + 0.023*"win" + 0.023*"gold" + 0.022*"skating" + 0.015*"valieva" + 0.015*"figure_skating" + 0.015*"kamila"'),
#  (4,
#   '0.057*"winter" + 0.051*"beijing" + 0.039*"china" + 0.020*"taiwan" + 0.017*"beijing2022" + 0.013*"end" + 0.013*"propaganda" + 0.013*"event" + 0.012*"games" + 0.011*"chinese"'),
#  (5,
# ...

# %%
#name topics:
o_2022['topic_name'] = None
o_2022.loc[o_2022['topic'] == 0, 'topic_name'] = 'FrozenFin'
o_2022.loc[o_2022['topic'] == 1, 'topic_name'] = 'Other'
o_2022.loc[o_2022['topic'] == 2, 'topic_name'] = 'ClosingCeremony'
o_2022.loc[o_2022['topic'] == 3, 'topic_name'] = 'KamilaValieva'
o_2022.loc[o_2022['topic'] == 4, 'topic_name'] = 'China'
o_2022.loc[o_2022['topic'] == 5, 'topic_name'] = 'EventSpecific'
# Out:
# /Users/jrod/anaconda3/envs/css_proj/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Overrides DF
#topic_df = pd.concat([o_2020, o_2022])
#topic_df.to_csv("../data/topic.csv", index=False)
