# %%
import pandas as pd
import utils

# %%
parsed = utils.parse_tweets(None, exists=True, downloads=False)

# %%
parsed.head()
# Out:
#                     id                        user_name       user_location  \
# 0  1418888645105356803               Abhishek Srivastav        Udupi, India
# 1  1418888377680678918         Saikhom Mirabai Channu🇮🇳      Manipur, India
# 2  1418889399081656321  International Hockey Federation            Lausanne
# 3  1418889398171566081                     Franz Halili  Bacoor, Calabarzon
# 4  1418889395416051717                           Happy💛             Lusaka
#
#                                     user_description         user_created  \
# 0               Trying to be mediocre in many things  2021-02-01 06:33:51
# 1      Indian weightlifter 48 kg category. Champion🏆  2018-04-07 10:10:22
# 2  Official International Hockey Federation Twitt...  2010-10-20 10:45:59
# 3  From the suburbs of Metro Manila\n\nHost of Ta...  2019-04-18 14:41:04
# 4  I love Jesus Christ | Music | Kids | Athletics...  2010-12-04 13:50:09
#
#    user_followers  user_friends                 date  \
# ...

# %%
len(parsed)
# Out:
# 395461
